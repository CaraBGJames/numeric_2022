# %%
import numpy as np
import pandas as pd
import context
import numlabs.lab7.sean_interactive as int
import matplotlib.pyplot as plt

# %%
import importlib
importlib.reload(int)
# Out:
# <module 'numlabs.lab7.sean_interactive' from '/Users/sean/repos/numeric_2022/numlabs/lab7/sean_interactive.py'>

# %%
int.interactive1(3,11,4,90,small=True)
# Out:
# dx/dt 25.000
#
# sqrt(g*H0) 10.000
#
# Interesting but smooth topo

# %%
int.interactive1(1,11,4,90,small=True)
# Out:
# dx/dt 25.000
#
# sqrt(g*H0) 10.000
#
# Flat Bottom

# %% [markdown]
# I created a smooth topography that matches the C-grid by creating an array with differing values and then taking the sine of u values and cos of v values, while keeping the first and last values the same so that the boundary conditions are met.
# The Topography changes $\eta$, u and v but most notable it significantly changes the velocity field.
