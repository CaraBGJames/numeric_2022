# %%
import context
from IPython.display import Image
import matplotlib.pyplot as plt
# make the plots happen inline
# %matplotlib inline  
# import the numpy array handling library
import numpy as np
# import the advection code from the numlabs directory
import numlabs.lab10.sean_advection as afs

# %%
import importlib
importlib.reload(afs)
# Out:
# <module 'numlabs.lab10.sean_advection' from '/Users/sean/repos/numeric_2022/numlabs/lab10/sean_advection.py'>

# %%
afs.advection3(600,1, lab_example=False)
# Out:
# array([[7.96136178e-128, 7.44474380e-129, 6.32594347e-131, ...,
#         6.89544670e-130, 6.89544670e-130, 7.44474380e-129],
#        [7.96136178e-128, 7.44474380e-129, 6.89544670e-130, ...,
#         6.89544670e-130, 6.89544670e-130, 7.44474380e-129],
#        [7.96136178e-128, 7.44474380e-129, 6.89544670e-130, ...,
#         6.89544670e-130, 6.89544670e-130, 7.44474380e-129],
#        ...,
#        [1.42273181e-009, 1.45991753e-009, 1.49840556e-009, ...,
#         1.49840556e-009, 1.53825055e-009, 1.57951696e-009],
#        [1.39757431e-009, 1.43388731e-009, 1.47146444e-009, ...,
#         1.47146444e-009, 1.51035836e-009, 1.55063133e-009],
#        [1.37300235e-009, 1.40846800e-009, 1.44516095e-009, ...,
#         1.44516095e-009, 1.48313193e-009, 1.52244109e-009]])

# %%
afs.advection3(600,2, lab_example=False)
# Out:
# array([[7.96136178e-128, 7.44474380e-129, 6.32594347e-131, ...,
#         6.89544670e-130, 6.89544670e-130, 7.44474380e-129],
#        [7.96136178e-128, 7.44474380e-129, 6.89544670e-130, ...,
#         6.89544670e-130, 6.89544670e-130, 7.44474380e-129],
#        [7.96136178e-128, 7.44474380e-129, 6.89544670e-130, ...,
#         6.89544670e-130, 6.89544670e-130, 7.44474380e-129],
#        ...,
#        [1.43761485e-009, 1.47525862e-009, 1.51422221e-009, ...,
#         1.51422221e-009, 1.55456395e-009, 1.59634535e-009],
#        [1.41214930e-009, 1.44890797e-009, 1.48694770e-009, ...,
#         1.48694770e-009, 1.52632472e-009, 1.56709837e-009],
#        [1.38727751e-009, 1.42317689e-009, 1.46031989e-009, ...,
#         1.46031989e-009, 1.49876080e-009, 1.53855682e-009]])
